# %%
#importing dependencies
import gmaps
import pandas as pd
from sqlalchemy import create_engine
from config import password
from config import gkey
gmaps.configure(api_key= gkey)
import plotly
import requests
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-42efe44b5e6e> in <module>
#       6 from config import gkey
#       7 gmaps.configure(api_key= gkey)
# ----> 8 import plotly
#       9 import requests
#      10 import json
#
# ModuleNotFoundError: No module named 'plotly'

# %%
file_path = 'data/MSP_neighborhoods.csv'
MSP_df = pd.read_csv(file_path, encoding = "utf-8")

# %%
MSP_df
# Out:
#             City           Neighborhood  Total population  \
# 0    Minneapolis               Armatage              5252
# 1    Minneapolis           Audubon Park              5318
# 2    Minneapolis               Bancroft              3523
# 3        St Paul  Battle Creek-Highwood             23757
# 4    Minneapolis               Beltrami              1177
# ..           ...                    ...               ...
# 97       St Paul              West Side             14594
# 98   Minneapolis               Whittier             14115
# 99   Minneapolis            Willard-Hay              9597
# 100  Minneapolis                 Windom              5416
# 101  Minneapolis            Windom Park              5612
#
#      Total population - Share - Margin of Error Total population - Share  \
# 0                                           296                     100%
# 1                                           311                     100%
# ...

# %%
MSP_df_reduced = MSP_df[["City", "Neighborhood", "Total population","Total households", "Public transportation - Share","Walked, biked, worked at home, or other - Share","Unemployment rate - Share","18-24 years - Share","25-34 years - Share","35-44 years - Share","45-54 years - Share","55-64 years - Share","65-74 years - Share","75-84 years - Share","85 years and older - Share","Unemployment rate - Share"]]
MSP_df_reduced.head()
# Out:
#           City           Neighborhood  Total population  Total households  \
# 0  Minneapolis               Armatage              5252              2127
# 1  Minneapolis           Audubon Park              5318              2268
# 2  Minneapolis               Bancroft              3523              1517
# 3      St Paul  Battle Creek-Highwood             23757              8107
# 4  Minneapolis               Beltrami              1177               449
#
#   Public transportation - Share  \
# 0                         6.91%
# 1                         7.73%
# 2                         9.16%
# 3                         4.64%
# 4                        15.73%
#
#   Walked, biked, worked at home, or other - Share Unemployment rate - Share  \
# 0                                          11.30%                     4.13%
# 1                                          12.43%                     3.45%
# 2                                          16.72%                     4.83%
# ...

# %%
# Rename the headers to be more explanatory
#renamed_df = reduced_df.rename(columns={"

# %%
# Target city
target_city = "Minneapolis, Minnesota"

# Define the endpoint URL
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Construct the query URL
target_url = f'{base_url}address={target_city}&key={gkey}'

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()

# Print the json
print(geo_data)
# Out:
# {'results': [{'address_components': [{'long_name': 'Minneapolis', 'short_name': 'Minneapolis', 'types': ['locality', 'political']}, {'long_name': 'Hennepin County', 'short_name': 'Hennepin County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Minnesota', 'short_name': 'MN', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Minneapolis, MN, USA', 'geometry': {'bounds': {'northeast': {'lat': 45.05125, 'lng': -93.193794}, 'southwest': {'lat': 44.890144, 'lng': -93.329163}}, 'location': {'lat': 44.977753, 'lng': -93.2650108}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 45.05125, 'lng': -93.193794}, 'southwest': {'lat': 44.890144, 'lng': -93.329163}}}, 'place_id': 'ChIJvbt3k5Azs1IRB-56L4TJn5M', 'types': ['locality', 'political']}], 'status': 'OK'}

# %%
# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Minneapolis",
#                     "short_name": "Minneapolis",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Hennepin County",
#                     "short_name": "Hennepin County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Minnesota",
#                     "short_name": "MN",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
# ...
